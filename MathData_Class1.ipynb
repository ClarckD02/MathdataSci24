# %% [markdown]
# <a href="https://colab.research.google.com/github/ClarckD02/MathdataSci24/blob/main/MathData_Class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Notes
# <img src= "https://www.colorado.com/_next/image?url=https%3A%2F%2Fapi.colorado.com%2Fsites%2Fdefault%2Ffiles%2Flegacy_drupal_7_images%2FTwin%2520Lakes_MUST%2520CREDIT_%2520mark%2520byzewski_0.jpg&w=3840&q=75" width=400>
#
#
# <img src= "https://cdn.sanity.io/images/oaglaatp/production/86a82e4fb0cc58a2d321c9a4a78533904964cd51-6119x3718.jpg?w=6119&h=3718&auto=format" width= 400>
#
# Example Notes

# %%
apples = 10

# %%
oranges = 8

# %%
total = apples + oranges

# %%
total
# Out:
# 18

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.random.random()

# %%
A
# Out:
# 0.031929780531708696

# %%
A = np.random.random((1,5))

# %%
A
# Out:
# array([[0.16305778, 0.95612452, 0.3482405 , 0.98963338, 0.76011642]])

# %%
B = np.random.random((1,5))

# %%
B
# Out:
# array([[0.73551656, 0.26060307, 0.23307247, 0.61463826, 0.55678194]])

# %%
A = A.T

# %%
B = B.T

# %%
plt.plot(A, B)

# %%
plt.plot(A, B, 'r')

# %%
x = np.random.random((100, 1))
y = np.random.random((100, 1))
plt.plot(x,y, 'g--')

# %%
print(A.shape, B.shape, x.shape, y.shape)
# Out:
# (5, 1) (5, 1) (100, 1) (100, 1)

# %%
Z = np.random.random((100,100))

# %%
Z.shape
# Out:
# (100, 100)

# %%
Z
# Out:
# array([[0.03363139, 0.01385416, 0.13974495, ..., 0.94760562, 0.69986272,
#         0.48474516],
#        [0.41727058, 0.7403514 , 0.13305328, ..., 0.5073766 , 0.36351395,
#         0.31964265],
#        [0.44271706, 0.15159193, 0.98929062, ..., 0.2570442 , 0.07241902,
#         0.73004035],
#        ...,
#        [0.91994615, 0.42935861, 0.45362192, ..., 0.65851359, 0.78187635,
#         0.81236682],
#        [0.65065345, 0.59244878, 0.51876573, ..., 0.59407895, 0.00413527,
#         0.5859453 ],
#        [0.6752093 , 0.09829191, 0.87031402, ..., 0.69964431, 0.74287293,
#         0.91384014]])

# %%
plt.imshow(Z)
